# %%
#import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config_challenge import weather_api_key

# %%
# starting url for weather map API call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high = 180.000, size = 2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities

cities = []

#identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
    #if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
#print the city count to confirm sufficient count
len(cities)
# Out:
# 726

# %%
#create an empty list to hold the weather data
city_data = []

#print the beginning of the logging

print("Beginning Data Retrieval      ")

print("------------------------------")

#create counters
record_count = 1
set_count = 1

#loop through all the cities in our list.
for i, city in enumerate(cities):
    
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count =1
        time.sleep(60)
        
        
    #create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #add 1 to the record count
    record_count += 1
    
    #Run an API request for each of the cities
    try:
        #parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        #parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        #conver the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%y-%m-%d %H:%M:S")
        
        #append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         "Current Description": city_description})
    #if an error is experienced, skip the city,
    except:
        print("City not found. Skipping ...")
        pass

#Indicate that Data Loading is complete.
print("------------------------------")

print("Data Retrieval Complete       ")

print("------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | jiexiu
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | churapcha
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | anito
# Processing Record 13 of Set 1 | pokaran
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | jerantut
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | namibe
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | adeje
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | lima
# Processing Record 23 of Set 1 | mbigou
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | inongo
# Processing Record 30 of Set 1 | barbar
# City not found. Skipping ...
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | itarema
# Processing Record 36 of Set 1 | lichinga
# Processing Record 37 of Set 1 | machilipatnam
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping ...
# Processing Record 40 of Set 1 | marondera
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | honningsvag
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping ...
# Processing Record 44 of Set 1 | saint-leu
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | lorengau
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | gazanjyk
# Processing Record 50 of Set 1 | koson
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping ...
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | celestun
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | andenes
# Processing Record 9 of Set 2 | havelock
# Processing Record 10 of Set 2 | seoul
# Processing Record 11 of Set 2 | dingle
# Processing Record 12 of Set 2 | erzincan
# Processing Record 13 of Set 2 | isangel
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | nioro
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping ...
# Processing Record 17 of Set 2 | coquimbo
# Processing Record 18 of Set 2 | provideniya
# Processing Record 19 of Set 2 | dibaya
# City not found. Skipping ...
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping ...
# Processing Record 22 of Set 2 | west wendover
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | cidreira
# Processing Record 25 of Set 2 | karratha
# Processing Record 26 of Set 2 | beringovskiy
# Processing Record 27 of Set 2 | grand island
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | dolbeau
# City not found. Skipping ...
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | flinders
# Processing Record 33 of Set 2 | yulara
# Processing Record 34 of Set 2 | cockburn harbour
# City not found. Skipping ...
# Processing Record 35 of Set 2 | port macquarie
# Processing Record 36 of Set 2 | murgab
# Processing Record 37 of Set 2 | gushikawa
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | warqla
# City not found. Skipping ...
# Processing Record 40 of Set 2 | manakara
# Processing Record 41 of Set 2 | fayaoue
# Processing Record 42 of Set 2 | rawannawi
# City not found. Skipping ...
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | ust-donetskiy
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | algiers
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | fukue
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | olinda
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | kashira
# Processing Record 3 of Set 3 | tumannyy
# City not found. Skipping ...
# Processing Record 4 of Set 3 | enumclaw
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping ...
# Processing Record 6 of Set 3 | namtsy
# Processing Record 7 of Set 3 | sinnamary
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | qandala
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | adrar
# Processing Record 12 of Set 3 | formoso do araguaia
# City not found. Skipping ...
# Processing Record 13 of Set 3 | sept-iles
# Processing Record 14 of Set 3 | port hardy
# Processing Record 15 of Set 3 | moanda
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | chapais
# Processing Record 18 of Set 3 | kavieng
# Processing Record 19 of Set 3 | fairbanks
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | touros
# Processing Record 22 of Set 3 | gobabis
# Processing Record 23 of Set 3 | rock sound
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | goiatuba
# Processing Record 26 of Set 3 | ramsar
# Processing Record 27 of Set 3 | necochea
# Processing Record 28 of Set 3 | panama city
# Processing Record 29 of Set 3 | katsuura
# Processing Record 30 of Set 3 | tagusao
# Processing Record 31 of Set 3 | kudahuvadhoo
# Processing Record 32 of Set 3 | gat
# Processing Record 33 of Set 3 | tocache
# Processing Record 34 of Set 3 | hokitika
# Processing Record 35 of Set 3 | crab hill
# City not found. Skipping ...
# Processing Record 36 of Set 3 | kisangani
# Processing Record 37 of Set 3 | taolanaro
# City not found. Skipping ...
# Processing Record 38 of Set 3 | rojhan
# Processing Record 39 of Set 3 | bilibino
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | mabaruma
# Processing Record 42 of Set 3 | kahului
# Processing Record 43 of Set 3 | nouadhibou
# Processing Record 44 of Set 3 | fuyang
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | illoqqortoormiut
# City not found. Skipping ...
# Processing Record 47 of Set 3 | kloulklubed
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | mergui
# City not found. Skipping ...
# Processing Record 50 of Set 3 | padang
# Processing Record 1 of Set 4 | udachnyy
# Processing Record 2 of Set 4 | bubaque
# Processing Record 3 of Set 4 | maniwaki
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | vardo
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | nantucket
# Processing Record 8 of Set 4 | kununurra
# Processing Record 9 of Set 4 | anloga
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | cachoeira do sul
# Processing Record 12 of Set 4 | hirara
# Processing Record 13 of Set 4 | teknaf
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | kaeo
# Processing Record 16 of Set 4 | tandil
# Processing Record 17 of Set 4 | imbituba
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | vieksniai
# Processing Record 21 of Set 4 | nanortalik
# Processing Record 22 of Set 4 | busselton
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | san lorenzo
# Processing Record 25 of Set 4 | lodwar
# Processing Record 26 of Set 4 | fortuna
# Processing Record 27 of Set 4 | albania
# Processing Record 28 of Set 4 | maldonado
# Processing Record 29 of Set 4 | bom jesus da lapa
# Processing Record 30 of Set 4 | buala
# Processing Record 31 of Set 4 | los llanos de aridane
# Processing Record 32 of Set 4 | homer
# Processing Record 33 of Set 4 | broken hill
# Processing Record 34 of Set 4 | flin flon
# Processing Record 35 of Set 4 | san quintin
# Processing Record 36 of Set 4 | hasaki
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | laguna
# Processing Record 40 of Set 4 | nadym
# Processing Record 41 of Set 4 | camopi
# Processing Record 42 of Set 4 | aksu
# Processing Record 43 of Set 4 | belaya gora
# Processing Record 44 of Set 4 | maykain
# City not found. Skipping ...
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | vao
# Processing Record 48 of Set 4 | tiksi
# Processing Record 49 of Set 4 | oistins
# Processing Record 50 of Set 4 | hilton head island
# Processing Record 1 of Set 5 | challans
# Processing Record 2 of Set 5 | yellowknife
# Processing Record 3 of Set 5 | kidal
# Processing Record 4 of Set 5 | jaguaribe
# Processing Record 5 of Set 5 | panaba
# Processing Record 6 of Set 5 | baijiantan
# Processing Record 7 of Set 5 | nuevo progreso
# Processing Record 8 of Set 5 | thompson
# Processing Record 9 of Set 5 | lavrentiya
# Processing Record 10 of Set 5 | bathsheba
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | half moon bay
# Processing Record 13 of Set 5 | bintulu
# Processing Record 14 of Set 5 | klaksvik
# Processing Record 15 of Set 5 | semme
# Processing Record 16 of Set 5 | nhulunbuy
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | hovd
# Processing Record 19 of Set 5 | dunedin
# Processing Record 20 of Set 5 | cajnice
# Processing Record 21 of Set 5 | louisbourg
# City not found. Skipping ...
# Processing Record 22 of Set 5 | alekseyevsk
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | pita
# Processing Record 25 of Set 5 | attawapiskat
# City not found. Skipping ...
# Processing Record 26 of Set 5 | stoyba
# City not found. Skipping ...
# Processing Record 27 of Set 5 | dipalpur
# Processing Record 28 of Set 5 | grand river south east
# City not found. Skipping ...
# Processing Record 29 of Set 5 | kawalu
# Processing Record 30 of Set 5 | pimentel
# Processing Record 31 of Set 5 | farafangana
# Processing Record 32 of Set 5 | ketchikan
# Processing Record 33 of Set 5 | aquiraz
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping ...
# Processing Record 35 of Set 5 | mangalia
# Processing Record 36 of Set 5 | semporna
# Processing Record 37 of Set 5 | nishihara
# Processing Record 38 of Set 5 | bani walid
# Processing Record 39 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 5 | tura
# Processing Record 41 of Set 5 | mayo
# Processing Record 42 of Set 5 | yarada
# Processing Record 43 of Set 5 | quatre cocos
# Processing Record 44 of Set 5 | sioux lookout
# Processing Record 45 of Set 5 | namatanai
# Processing Record 46 of Set 5 | victoria
# Processing Record 47 of Set 5 | krasnoselkup
# Processing Record 48 of Set 5 | ulaanbaatar
# Processing Record 49 of Set 5 | san rafael
# Processing Record 50 of Set 5 | bacuit
# City not found. Skipping ...
# Processing Record 1 of Set 6 | westport
# Processing Record 2 of Set 6 | inhambane
# Processing Record 3 of Set 6 | prince rupert
# Processing Record 4 of Set 6 | san carlos de bariloche
# Processing Record 5 of Set 6 | ouadda
# Processing Record 6 of Set 6 | machiques
# Processing Record 7 of Set 6 | alexandria
# Processing Record 8 of Set 6 | henties bay
# Processing Record 9 of Set 6 | longyearbyen
# Processing Record 10 of Set 6 | tautira
# Processing Record 11 of Set 6 | talnakh
# Processing Record 12 of Set 6 | hopelchen
# Processing Record 13 of Set 6 | sola
# Processing Record 14 of Set 6 | mafeteng
# Processing Record 15 of Set 6 | carnarvon
# Processing Record 16 of Set 6 | lagoa
# Processing Record 17 of Set 6 | panguipulli
# Processing Record 18 of Set 6 | mys shmidta
# City not found. Skipping ...
# Processing Record 19 of Set 6 | athgarh
# City not found. Skipping ...
# Processing Record 20 of Set 6 | goderich
# Processing Record 21 of Set 6 | maymyo
# Processing Record 22 of Set 6 | virginia beach
# Processing Record 23 of Set 6 | alotau
# City not found. Skipping ...
# Processing Record 24 of Set 6 | alpena
# Processing Record 25 of Set 6 | cosmopolis
# Processing Record 26 of Set 6 | hendek
# Processing Record 27 of Set 6 | tabuk
# Processing Record 28 of Set 6 | nouakchott
# Processing Record 29 of Set 6 | wattens
# Processing Record 30 of Set 6 | macon
# Processing Record 31 of Set 6 | saldanha
# Processing Record 32 of Set 6 | aykhal
# Processing Record 33 of Set 6 | sabha
# Processing Record 34 of Set 6 | novikovo
# Processing Record 35 of Set 6 | naze
# Processing Record 36 of Set 6 | emba
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | luqiao
# Processing Record 39 of Set 6 | aswan
# Processing Record 40 of Set 6 | maridi
# Processing Record 41 of Set 6 | holesov
# Processing Record 42 of Set 6 | wisconsin rapids
# Processing Record 43 of Set 6 | broome
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | karamay
# City not found. Skipping ...
# Processing Record 46 of Set 6 | armizonskoye
# Processing Record 47 of Set 6 | athabasca
# Processing Record 48 of Set 6 | jalingo
# Processing Record 49 of Set 6 | aitape
# Processing Record 50 of Set 6 | alyangula
# Processing Record 1 of Set 7 | dana point
# Processing Record 2 of Set 7 | bereznik
# Processing Record 3 of Set 7 | darhan
# Processing Record 4 of Set 7 | kailua
# Processing Record 5 of Set 7 | taquaritinga do norte
# Processing Record 6 of Set 7 | mehamn
# Processing Record 7 of Set 7 | eresos
# Processing Record 8 of Set 7 | biu
# Processing Record 9 of Set 7 | kazalinsk
# City not found. Skipping ...
# Processing Record 10 of Set 7 | paracuru
# Processing Record 11 of Set 7 | roald
# Processing Record 12 of Set 7 | moss vale
# Processing Record 13 of Set 7 | sakakah
# Processing Record 14 of Set 7 | staryy krym
# Processing Record 15 of Set 7 | toccoa
# Processing Record 16 of Set 7 | praia
# Processing Record 17 of Set 7 | impfondo
# Processing Record 18 of Set 7 | praia da vitoria
# Processing Record 19 of Set 7 | esmeraldas
# Processing Record 20 of Set 7 | mutsamudu
# City not found. Skipping ...
# Processing Record 21 of Set 7 | beaufort
# Processing Record 22 of Set 7 | puerto ayacucho
# Processing Record 23 of Set 7 | vila velha
# Processing Record 24 of Set 7 | codrington
# Processing Record 25 of Set 7 | guilin
# Processing Record 26 of Set 7 | matay
# Processing Record 27 of Set 7 | batman
# Processing Record 28 of Set 7 | bonavista
# Processing Record 29 of Set 7 | salalah
# Processing Record 30 of Set 7 | north bend
# Processing Record 31 of Set 7 | faanui
# Processing Record 32 of Set 7 | san-pedro
# Processing Record 33 of Set 7 | guasdualito
# Processing Record 34 of Set 7 | mago
# Processing Record 35 of Set 7 | lata
# Processing Record 36 of Set 7 | amderma
# City not found. Skipping ...
# Processing Record 37 of Set 7 | dembi dolo
# Processing Record 38 of Set 7 | clyde river
# Processing Record 39 of Set 7 | huarmey
# Processing Record 40 of Set 7 | pevek
# Processing Record 41 of Set 7 | kontagora
# Processing Record 42 of Set 7 | ternate
# Processing Record 43 of Set 7 | sao felix do xingu
# Processing Record 44 of Set 7 | vila
# Processing Record 45 of Set 7 | san cristobal
# Processing Record 46 of Set 7 | tunduru
# City not found. Skipping ...
# Processing Record 47 of Set 7 | sattahip
# Processing Record 48 of Set 7 | sao filipe
# Processing Record 49 of Set 7 | sompeta
# Processing Record 50 of Set 7 | sibolga
# Processing Record 1 of Set 8 | ostrovnoy
# Processing Record 2 of Set 8 | raudeberg
# Processing Record 3 of Set 8 | tonekabon
# Processing Record 4 of Set 8 | bengkulu
# Processing Record 5 of Set 8 | leningradskiy
# Processing Record 6 of Set 8 | timmins
# Processing Record 7 of Set 8 | the valley
# Processing Record 8 of Set 8 | ust-kuyga
# Processing Record 9 of Set 8 | narsaq
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | svetlyy
# Processing Record 12 of Set 8 | boa vista
# Processing Record 13 of Set 8 | cockburn town
# Processing Record 14 of Set 8 | umzimvubu
# City not found. Skipping ...
# Processing Record 15 of Set 8 | myitkyina
# Processing Record 16 of Set 8 | old shinyanga
# Processing Record 17 of Set 8 | chivacoa
# Processing Record 18 of Set 8 | yabelo
# Processing Record 19 of Set 8 | iranshahr
# Processing Record 20 of Set 8 | inirida
# Processing Record 21 of Set 8 | jardim
# Processing Record 22 of Set 8 | tomatlan
# Processing Record 23 of Set 8 | gorontalo
# Processing Record 24 of Set 8 | nizhniye sergi
# Processing Record 25 of Set 8 | manta
# Processing Record 26 of Set 8 | mwinilunga
# Processing Record 27 of Set 8 | port blair
# Processing Record 28 of Set 8 | pacific grove
# Processing Record 29 of Set 8 | cravo norte
# Processing Record 30 of Set 8 | nabire
# Processing Record 31 of Set 8 | leshukonskoye
# Processing Record 32 of Set 8 | grand-santi
# Processing Record 33 of Set 8 | tazovskiy
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | hualmay
# Processing Record 36 of Set 8 | aripuana
# Processing Record 37 of Set 8 | lebyazhye
# Processing Record 38 of Set 8 | ginda
# Processing Record 39 of Set 8 | cheuskiny
# City not found. Skipping ...
# Processing Record 40 of Set 8 | lyubinskiy
# Processing Record 41 of Set 8 | ma-ao
# Processing Record 42 of Set 8 | rayevskiy
# Processing Record 43 of Set 8 | salta
# Processing Record 44 of Set 8 | belyy yar
# Processing Record 45 of Set 8 | lakes entrance
# Processing Record 46 of Set 8 | arman
# Processing Record 47 of Set 8 | kalabo
# Processing Record 48 of Set 8 | port hedland
# Processing Record 49 of Set 8 | nueva imperial
# Processing Record 50 of Set 8 | ilinsko-podomskoye
# City not found. Skipping ...
# Processing Record 1 of Set 9 | saint-georges
# Processing Record 2 of Set 9 | coahuayana
# Processing Record 3 of Set 9 | galle
# Processing Record 4 of Set 9 | college
# Processing Record 5 of Set 9 | tondano
# Processing Record 6 of Set 9 | samarai
# Processing Record 7 of Set 9 | shengjin
# Processing Record 8 of Set 9 | maunabo
# Processing Record 9 of Set 9 | kenai
# Processing Record 10 of Set 9 | boshnyakovo
# Processing Record 11 of Set 9 | victor harbor
# Processing Record 12 of Set 9 | labuhan
# Processing Record 13 of Set 9 | poya
# Processing Record 14 of Set 9 | nara
# Processing Record 15 of Set 9 | waipawa
# Processing Record 16 of Set 9 | enid
# Processing Record 17 of Set 9 | deputatskiy
# Processing Record 18 of Set 9 | ouahigouya
# Processing Record 19 of Set 9 | mitilinioi
# City not found. Skipping ...
# Processing Record 20 of Set 9 | winnemucca
# Processing Record 21 of Set 9 | marsabit
# Processing Record 22 of Set 9 | raga
# Processing Record 23 of Set 9 | ermoupolis
# Processing Record 24 of Set 9 | vanimo
# Processing Record 25 of Set 9 | bandundu
# Processing Record 26 of Set 9 | aberdeen
# Processing Record 27 of Set 9 | porosozero
# Processing Record 28 of Set 9 | tarusa
# Processing Record 29 of Set 9 | kikwit
# Processing Record 30 of Set 9 | byron bay
# Processing Record 31 of Set 9 | yar-sale
# Processing Record 32 of Set 9 | kalmunai
# Processing Record 33 of Set 9 | port moresby
# Processing Record 34 of Set 9 | mujiayingzi
# Processing Record 35 of Set 9 | atambua
# Processing Record 36 of Set 9 | geraldton
# Processing Record 37 of Set 9 | canyon lake
# Processing Record 38 of Set 9 | annaberg-buchholz
# Processing Record 39 of Set 9 | baturite
# Processing Record 40 of Set 9 | skjervoy
# Processing Record 41 of Set 9 | meulaboh
# Processing Record 42 of Set 9 | teacapan
# Processing Record 43 of Set 9 | de-kastri
# Processing Record 44 of Set 9 | iwanai
# Processing Record 45 of Set 9 | miles city
# Processing Record 46 of Set 9 | saint-joseph
# Processing Record 47 of Set 9 | aklavik
# Processing Record 48 of Set 9 | bairiki
# Processing Record 49 of Set 9 | mahibadhoo
# Processing Record 50 of Set 9 | pemba
# Processing Record 1 of Set 10 | erenhot
# Processing Record 2 of Set 10 | vodnyy
# Processing Record 3 of Set 10 | nadvoitsy
# Processing Record 4 of Set 10 | mustasaari
# Processing Record 5 of Set 10 | rio gallegos
# Processing Record 6 of Set 10 | ekibastuz
# Processing Record 7 of Set 10 | tubmanburg
# Processing Record 8 of Set 10 | alofi
# Processing Record 9 of Set 10 | oyama
# Processing Record 10 of Set 10 | changying
# Processing Record 11 of Set 10 | kualakapuas
# Processing Record 12 of Set 10 | banda aceh
# Processing Record 13 of Set 10 | salaga
# Processing Record 14 of Set 10 | mount isa
# Processing Record 15 of Set 10 | rochegda
# Processing Record 16 of Set 10 | vila franca do campo
# Processing Record 17 of Set 10 | shenjiamen
# Processing Record 18 of Set 10 | port lincoln
# Processing Record 19 of Set 10 | marsa matruh
# Processing Record 20 of Set 10 | sao miguel do araguaia
# Processing Record 21 of Set 10 | mortka
# Processing Record 22 of Set 10 | shingu
# Processing Record 23 of Set 10 | santa rosalia
# Processing Record 24 of Set 10 | havre-saint-pierre
# Processing Record 25 of Set 10 | pelym
# Processing Record 26 of Set 10 | lolua
# City not found. Skipping ...
# Processing Record 27 of Set 10 | marcona
# City not found. Skipping ...
# Processing Record 28 of Set 10 | saleaula
# City not found. Skipping ...
# Processing Record 29 of Set 10 | kanigoro
# Processing Record 30 of Set 10 | seddon
# Processing Record 31 of Set 10 | watsa
# Processing Record 32 of Set 10 | te anau
# Processing Record 33 of Set 10 | tres passos
# Processing Record 34 of Set 10 | kortkeros
# Processing Record 35 of Set 10 | tahta
# Processing Record 36 of Set 10 | voi
# Processing Record 37 of Set 10 | palabuhanratu
# City not found. Skipping ...
# Processing Record 38 of Set 10 | acari
# Processing Record 39 of Set 10 | santa cruz
# Processing Record 40 of Set 10 | kopayhorod
# Processing Record 41 of Set 10 | concarneau
# Processing Record 42 of Set 10 | neyvo-shaytanskiy
# Processing Record 43 of Set 10 | bom sucesso
# Processing Record 44 of Set 10 | vanavara
# Processing Record 45 of Set 10 | talcahuano
# Processing Record 46 of Set 10 | bandarbeyla
# Processing Record 47 of Set 10 | faya
# Processing Record 48 of Set 10 | barabai
# Processing Record 49 of Set 10 | morondava
# Processing Record 50 of Set 10 | madras
# Processing Record 1 of Set 11 | naqadeh
# Processing Record 2 of Set 11 | barawe
# City not found. Skipping ...
# Processing Record 3 of Set 11 | ferme-neuve
# Processing Record 4 of Set 11 | boissevain
# Processing Record 5 of Set 11 | poum
# Processing Record 6 of Set 11 | ixtapa
# Processing Record 7 of Set 11 | bontang
# Processing Record 8 of Set 11 | libreville
# Processing Record 9 of Set 11 | mount gambier
# Processing Record 10 of Set 11 | anadyr
# Processing Record 11 of Set 11 | puerto colombia
# Processing Record 12 of Set 11 | fillira
# City not found. Skipping ...
# Processing Record 13 of Set 11 | minna
# Processing Record 14 of Set 11 | mrirt
# City not found. Skipping ...
# Processing Record 15 of Set 11 | kihei
# Processing Record 16 of Set 11 | maceio
# Processing Record 17 of Set 11 | cumaribo
# City not found. Skipping ...
# Processing Record 18 of Set 11 | sigli
# Processing Record 19 of Set 11 | wajir
# Processing Record 20 of Set 11 | yeniseysk
# Processing Record 21 of Set 11 | dodola
# Processing Record 22 of Set 11 | kruisfontein
# Processing Record 23 of Set 11 | emerald
# Processing Record 24 of Set 11 | yerbogachen
# Processing Record 25 of Set 11 | ambon
# Processing Record 26 of Set 11 | guangshui
# Processing Record 27 of Set 11 | hohhot
# Processing Record 28 of Set 11 | acapulco
# Processing Record 29 of Set 11 | same
# Processing Record 30 of Set 11 | jiangyan
# Processing Record 31 of Set 11 | putina
# Processing Record 32 of Set 11 | tual
# Processing Record 33 of Set 11 | cardston
# Processing Record 34 of Set 11 | sunyani
# Processing Record 35 of Set 11 | tezu
# Processing Record 36 of Set 11 | mount pleasant
# Processing Record 37 of Set 11 | saint anthony
# Processing Record 38 of Set 11 | rawah
# Processing Record 39 of Set 11 | goma
# Processing Record 40 of Set 11 | grand gaube
# Processing Record 41 of Set 11 | sambava
# Processing Record 42 of Set 11 | mocoa
# Processing Record 43 of Set 11 | payson
# Processing Record 44 of Set 11 | fredericksburg
# Processing Record 45 of Set 11 | asifabad
# Processing Record 46 of Set 11 | kamenka
# Processing Record 47 of Set 11 | rio grande
# Processing Record 48 of Set 11 | omsukchan
# Processing Record 49 of Set 11 | eydhafushi
# Processing Record 50 of Set 11 | volterra
# Processing Record 1 of Set 12 | jemnice
# Processing Record 2 of Set 12 | camana
# Processing Record 3 of Set 12 | dali
# Processing Record 4 of Set 12 | mogadishu
# Processing Record 5 of Set 12 | road town
# Processing Record 6 of Set 12 | abatskoye
# Processing Record 7 of Set 12 | nassau
# Processing Record 8 of Set 12 | tecoanapa
# Processing Record 9 of Set 12 | samana
# Processing Record 10 of Set 12 | omboue
# Processing Record 11 of Set 12 | tawau
# Processing Record 12 of Set 12 | yatou
# Processing Record 13 of Set 12 | zhigansk
# Processing Record 14 of Set 12 | plettenberg bay
# Processing Record 15 of Set 12 | hemnesberget
# Processing Record 16 of Set 12 | ardahan
# Processing Record 17 of Set 12 | verkhnetulomskiy
# Processing Record 18 of Set 12 | we
# City not found. Skipping ...
# Processing Record 19 of Set 12 | luanda
# Processing Record 20 of Set 12 | igarka
# Processing Record 21 of Set 12 | saquarema
# Processing Record 22 of Set 12 | billings
# Processing Record 23 of Set 12 | richards bay
# Processing Record 24 of Set 12 | sri aman
# Processing Record 25 of Set 12 | chulman
# Processing Record 26 of Set 12 | qunduz
# Processing Record 27 of Set 12 | anda
# Processing Record 28 of Set 12 | kamenskoye
# City not found. Skipping ...
# Processing Record 29 of Set 12 | kirakira
# Processing Record 30 of Set 12 | tall kayf
# Processing Record 31 of Set 12 | humberto de campos
# Processing Record 32 of Set 12 | kristiinankaupunki
# Processing Record 33 of Set 12 | husavik
# Processing Record 34 of Set 12 | irbil
# Processing Record 35 of Set 12 | itacarambi
# Processing Record 36 of Set 12 | marfino
# Processing Record 37 of Set 12 | coruripe
# Processing Record 38 of Set 12 | honiara
# Processing Record 39 of Set 12 | surt
# Processing Record 40 of Set 12 | wagar
# Processing Record 41 of Set 12 | moron
# Processing Record 42 of Set 12 | la rioja
# Processing Record 43 of Set 12 | am timan
# Processing Record 44 of Set 12 | asau
# Processing Record 45 of Set 12 | coetupo
# City not found. Skipping ...
# Processing Record 46 of Set 12 | siguiri
# Processing Record 47 of Set 12 | wanning
# Processing Record 48 of Set 12 | sabla
# Processing Record 49 of Set 12 | gulshat
# City not found. Skipping ...
# Processing Record 50 of Set 12 | gamba
# Processing Record 1 of Set 13 | vetapalem
# Processing Record 2 of Set 13 | vicosa
# Processing Record 3 of Set 13 | vostok
# Processing Record 4 of Set 13 | tabou
# Processing Record 5 of Set 13 | chegdomyn
# Processing Record 6 of Set 13 | yurya
# City not found. Skipping ...
# Processing Record 7 of Set 13 | katherine
# Processing Record 8 of Set 13 | edd
# Processing Record 9 of Set 13 | tessalit
# Processing Record 10 of Set 13 | alta gracia
# Processing Record 11 of Set 13 | zomba
# Processing Record 12 of Set 13 | capitao poco
# Processing Record 13 of Set 13 | inta
# Processing Record 14 of Set 13 | kedrovoye
# Processing Record 15 of Set 13 | metu
# Processing Record 16 of Set 13 | tarrafal
# Processing Record 17 of Set 13 | matto
# City not found. Skipping ...
# Processing Record 18 of Set 13 | gold coast
# Processing Record 19 of Set 13 | aflu
# City not found. Skipping ...
# Processing Record 20 of Set 13 | mulchen
# Processing Record 21 of Set 13 | abu samrah
# Processing Record 22 of Set 13 | pousat
# City not found. Skipping ...
# Processing Record 23 of Set 13 | evensk
# Processing Record 24 of Set 13 | cairns
# Processing Record 25 of Set 13 | coari
# Processing Record 26 of Set 13 | camacha
# Processing Record 27 of Set 13 | severodvinsk
# Processing Record 28 of Set 13 | sao geraldo do araguaia
# Processing Record 29 of Set 13 | palafrugell
# Processing Record 30 of Set 13 | ahipara
# Processing Record 31 of Set 13 | coihaique
# Processing Record 32 of Set 13 | vestmanna
# Processing Record 33 of Set 13 | nizwa
# Processing Record 34 of Set 13 | ilhabela
# Processing Record 35 of Set 13 | tungor
# Processing Record 36 of Set 13 | sao jose da coroa grande
# Processing Record 37 of Set 13 | chimbote
# Processing Record 38 of Set 13 | port-gentil
# Processing Record 39 of Set 13 | diego de almagro
# Processing Record 40 of Set 13 | fort nelson
# Processing Record 41 of Set 13 | kupang
# Processing Record 42 of Set 13 | fort myers beach
# Processing Record 43 of Set 13 | fukumitsu
# Processing Record 44 of Set 13 | sechura
# Processing Record 45 of Set 13 | sur
# Processing Record 46 of Set 13 | genhe
# Processing Record 47 of Set 13 | saint-augustin
# Processing Record 48 of Set 13 | qaqortoq
# Processing Record 49 of Set 13 | staraya russa
# Processing Record 50 of Set 13 | sao joao da barra
# Processing Record 1 of Set 14 | karaul
# City not found. Skipping ...
# Processing Record 2 of Set 14 | ambatolampy
# Processing Record 3 of Set 14 | burica
# City not found. Skipping ...
# Processing Record 4 of Set 14 | ouallam
# Processing Record 5 of Set 14 | zigong
# Processing Record 6 of Set 14 | bowen
# Processing Record 7 of Set 14 | nuuk
# Processing Record 8 of Set 14 | selaphum
# Processing Record 9 of Set 14 | sulangan
# Processing Record 10 of Set 14 | roma
# Processing Record 11 of Set 14 | dubti
# Processing Record 12 of Set 14 | changping
# Processing Record 13 of Set 14 | kieta
# Processing Record 14 of Set 14 | oriximina
# Processing Record 15 of Set 14 | acajutla
# Processing Record 16 of Set 14 | shu
# Processing Record 17 of Set 14 | chihuahua
# Processing Record 18 of Set 14 | yelovo
# Processing Record 19 of Set 14 | lawrenceburg
# Processing Record 20 of Set 14 | tabiauea
# City not found. Skipping ...
# Processing Record 21 of Set 14 | bonaventure
# Processing Record 22 of Set 14 | makakilo city
# Processing Record 23 of Set 14 | fukuma
# Processing Record 24 of Set 14 | laela
# Processing Record 25 of Set 14 | arroyo
# Processing Record 26 of Set 14 | nikki
# Processing Record 27 of Set 14 | pundaguitan
# Processing Record 28 of Set 14 | ixchiguan
# Processing Record 29 of Set 14 | bone
# Processing Record 30 of Set 14 | mahur
# Processing Record 31 of Set 14 | carballo
# Processing Record 32 of Set 14 | lluta
# Processing Record 33 of Set 14 | nador
# Processing Record 34 of Set 14 | beira
# Processing Record 35 of Set 14 | matara
# Processing Record 36 of Set 14 | oia
# Processing Record 37 of Set 14 | terney
# Processing Record 38 of Set 14 | christchurch
# Processing Record 39 of Set 14 | carauari
# Processing Record 40 of Set 14 | teixeira
# Processing Record 41 of Set 14 | grindavik
# Processing Record 42 of Set 14 | zima
# Processing Record 43 of Set 14 | grande-riviere
# City not found. Skipping ...
# Processing Record 44 of Set 14 | halalo
# City not found. Skipping ...
# Processing Record 45 of Set 14 | tutoia
# Processing Record 46 of Set 14 | jiayuguan
# Processing Record 47 of Set 14 | napasar
# Processing Record 48 of Set 14 | dukat
# Processing Record 49 of Set 14 | fasa
# Processing Record 50 of Set 14 | tazmalt
# Processing Record 1 of Set 15 | thanh hoa
# Processing Record 2 of Set 15 | galesburg
# Processing Record 3 of Set 15 | harper
# Processing Record 4 of Set 15 | khandagayty
# Processing Record 5 of Set 15 | mitu
# Processing Record 6 of Set 15 | shipunovo
# Processing Record 7 of Set 15 | boddam
# Processing Record 8 of Set 15 | tuatapere
# Processing Record 9 of Set 15 | matamoros
# Processing Record 10 of Set 15 | turukhansk
# Processing Record 11 of Set 15 | coaldale
# Processing Record 12 of Set 15 | tanout
# Processing Record 13 of Set 15 | togur
# Processing Record 14 of Set 15 | trinidad
# Processing Record 15 of Set 15 | mkushi
# Processing Record 16 of Set 15 | jinchang
# Processing Record 17 of Set 15 | santa maria
# Processing Record 18 of Set 15 | ermelo
# Processing Record 19 of Set 15 | wajima
# Processing Record 20 of Set 15 | yazoo city
# Processing Record 21 of Set 15 | jining
# Processing Record 22 of Set 15 | griffith
# Processing Record 23 of Set 15 | simiti
# Processing Record 24 of Set 15 | astoria
# Processing Record 25 of Set 15 | blackwater
# Processing Record 26 of Set 15 | ust-ishim
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 668

# %%
#conver the array of dictionaries to a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Jiexiu  37.0244  111.9125     67.21        37           9
# 1          Castro -24.7911  -50.0119     67.69        76         100
# 2     Tuktoyaktuk  69.4541 -133.0374     34.25        74           8
# 3       Esperance -33.8667  121.9000     56.08        61         100
# 4         Ushuaia -54.8000  -68.3000     38.82        75          20
# 5       Churapcha  62.0025  132.4325     59.67        66          11
# 6        Cherskiy  68.7500  161.3000     37.44        60          26
# 7         Qaanaaq  77.4840  -69.3632     30.83        87         100
# 8            Hilo  19.7297 -155.0900     89.28        75           1
# 9  Severo-Kurilsk  50.6789  156.1250     43.43        88         100
#
#    Wind Speed Country              Date Current Description
# 0        2.08      CN  22-06-06 19:00:S           clear sky
# 1        7.90      BR  22-06-06 19:00:S     overcast clouds
# 2       11.25      CA  22-06-06 19:00:S           clear sky
# 3        3.71      AU  22-06-06 19:00:S     overcast clouds
# 4        5.75      AR  22-06-06 18:57:S          few clouds
# 5        2.17      RU  22-06-06 19:00:S          few clouds
# 6       10.20      RU  22-06-06 18:59:S    scattered clouds
# 7        4.45      GL  22-06-06 18:58:S          light snow
# 8        5.99      US  22-06-06 19:00:S           clear sky
# 9        5.37      RU  22-06-06 19:00:S     overcast clouds

# %%
#rearrange the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Jiexiu      CN  37.0244  111.9125     67.21        37           9
# 1       Castro      BR -24.7911  -50.0119     67.69        76         100
# 2  Tuktoyaktuk      CA  69.4541 -133.0374     34.25        74           8
# 3    Esperance      AU -33.8667  121.9000     56.08        61         100
# 4      Ushuaia      AR -54.8000  -68.3000     38.82        75          20
#
#    Wind Speed Current Description
# 0        2.08           clear sky
# 1        7.90     overcast clouds
# 2       11.25           clear sky
# 3        3.71     overcast clouds
# 4        5.75          few clouds

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

#export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
